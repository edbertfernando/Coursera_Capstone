# %%
# !pip install bs4
# !pip install requests

# %%
# !pip install geocoder

# %%
import pandas as pd
import numpy as np
import requests
import io
# import k-means from clustering stage
from sklearn.cluster import KMeans
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
sg = pd.read_csv("File:/content/Singapore_Postal.csv")
sg.head()
# Out:
#    Postcode General Location            Regions
# 0     48616    Raffles Place  Central Singapore
# 1     69531            Cecil  Central Singapore
# 2     18985           Marina  Central Singapore
# 3     59108    People's Park  Central Singapore
# 4     79914            Anson  Central Singapore

# %%
# Grouping data to find Regions with highest number of area
sg.groupby('Regions').count()
# Out:
#                    Postcode  General Location
# Regions
# Central Singapore        22                22
# North East               16                16
# North West               15                15
# South East               15                15
# South West               13                13

# %%
# Read each of Singapore's location respective Latitude and Longitude
sg_latlong = pd.read_csv("File:/content/Singapore LongLang.csv")

# %%
# Combine the two dataframe
sg = sg.join(sg_latlong)
sg.head()
# Out:
#    Postcode General Location            Regions  Latitude  Longitude
# 0     48616    Raffles Place  Central Singapore   1.28468  103.85070
# 1     69531            Cecil  Central Singapore   1.28135  103.84909
# 2     18985           Marina  Central Singapore   1.28077  103.85266
# 3     59108    People's Park  Central Singapore   1.28425  103.84278
# 4     79914            Anson  Central Singapore   1.27488  103.84495

# %%
# Visualize the latitude and longitude to a map
from geopy.geocoders import Nominatim
import folium
address = 'Singapore, Singapore'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# Create map of Singapore using latitude and longitude values
map_sg = folium.Map(location=[latitude, longitude], zoom_start=10)

# Add markers to map
for lat, lng, borough, neighborhood in zip(sg['Latitude'], sg['Longitude'], sg['General Location'], sg['Regions']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sg)  
    
map_sg
# Out:
# /usr/local/lib/python3.7/dist-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# ...

# %%
# Slice dataframe & create new dataframe of central
central = sg[sg['Regions'] == 'Central Singapore'].reset_index(drop=True)

# Geographical coordinates of Central Singapore is as follow (obtained from worldpostalcode.com)
central_latitude = 1.2904753
central_longitude = 103.8520359

# Create map of Central Singapore using latitude and longitude values
map_central = folium.Map(location=[central_latitude, central_longitude], zoom_start=11)

# Add markers to map
for lat, lng, label in zip(central['Latitude'], central['Longitude'], central['General Location']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_central)  
    
map_central
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
# Slice dataframe & create new dataframe of North East
ne = sg[sg['Regions'] == 'North East'].reset_index(drop=True)

# Geographical coordinates of North east Singapore is as follow (obtained from worldpostalcode.com)
ne_latitude = 1.37694165
ne_longitude = 103.927369390179

# Create map of North East Singapore using latitude and longitude values
map_ne = folium.Map(location=[ne_latitude, ne_longitude], zoom_start=11)

# Add markers to map
for lat, lng, label in zip(ne['Latitude'], ne['Longitude'], ne['General Location']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ne)  
    
map_ne
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
# Slice dataframe & create new dataframe of North West
nw = sg[sg['Regions'] == 'North West'].reset_index(drop=True)

# Geographical coordinates of Central Singapore is as follow (obtained from worldpostalcode.com)
nw_latitude = 1.38937855
nw_longitude = 103.782749408728

# Create map of North West Singapore using latitude and longitude values
map_nw = folium.Map(location=[nw_latitude, nw_longitude], zoom_start=11)

# Add markers to map
for lat, lng, label in zip(nw['Latitude'], nw['Longitude'], nw['General Location']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_nw)  
    
map_nw
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
# Slice dataframe & create new dataframe of South East
se = sg[sg['Regions'] == 'South East'].reset_index(drop=True)

# Geographical coordinates of South East Singapore is as follow (obtained from worldpostalcode.com)
se_latitude = 1.3333174
se_longitude = 104.007519714973

# Create map of South East Singapore using latitude and longitude values
map_se = folium.Map(location=[se_latitude, se_longitude], zoom_start=11)

# Add markers to map
for lat, lng, label in zip(se['Latitude'], se['Longitude'], se['General Location']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_se)  
    
map_se
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
# Slice dataframe & create new dataframe of South West
sw = sg[sg['Regions'] == 'South West'].reset_index(drop=True)

# Geographical coordinates of South West Singapore is as follow (obtained from worldpostalcode.com)
sw_latitude = 1.29494015
sw_longitude = 103.703142048898

# Create map of South West Singapore using latitude and longitude values
map_sw = folium.Map(location=[sw_latitude, sw_longitude], zoom_start=11)

# Add markers to map
for lat, lng, label in zip(sw['Latitude'], sw['Longitude'], sw['General Location']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sw)  
    
map_sw
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
# Tranform JSON file into a pandas dataframe
from pandas.io.json import json_normalize 

# Define Foursquare Credentials and Version
CLIENT_ID = 'EJZKNO4IYC0BSX4UDJQGUTMVVJYJAABCQPKV5FZSVODUJD42' # your Foursquare ID
CLIENT_SECRET = 'O041KSXYOT4453CIT55PVCD3JFSU5CWNL3AFNC01P34Y3OZZ' # your Foursquare Secret
VERSION = '20180604'

# Explore the first neighborhood in our dataframe
# Get the neighborhood's latitude and longitude values.
neighborhood_latitude = central.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = central.loc[0, 'Longitude'] # neighborhood longitude value
neighborhood_name = central.loc[0, 'General Location'] # neighborhood name

# Get the top 100 venues that are in Central Singapore within a radius of 500 meters
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# Send the GET request and examine the resutls
results = requests.get(url).json()

# Borrow the get_category_type function from the Foursquare lab.
# Function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Clean the json and structure it into a pandas dataframe
venues = results['response']['groups'][0]['items']    
nearby_venues = json_normalize(venues) # flatten JSON

# Filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# Filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# Clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
print('{} venues were returned by Foursquare for Central Singapore.'.format(nearby_venues.shape[0]))
nearby_venues.head()
# Out:
# 100 venues were returned by Foursquare for Central Singapore.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                 name               categories       lat         lng
# 0      Virgin Active     Gym / Fitness Center  1.284608  103.850815
# 1         1-Altitude             Cocktail Bar  1.284794  103.851151
# 2     The Salad Shop              Salad Place  1.285523  103.851177
# 3         CULINARYON  Comfort Food Restaurant  1.284876  103.850933
# 4  The Sandwich Shop           Sandwich Place  1.284266  103.852673

# %%
# North East Singapore neighborhood
# Explore the first neighborhood in our dataframe
# Get the neighborhood's latitude and longitude values.
neighborhood_latitude = ne.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = ne.loc[0, 'Longitude'] # neighborhood longitude value
neighborhood_name = ne.loc[0, 'General Location'] # neighborhood name

# Get the top 100 venues that are in North East Singapore within a radius of 500 meters
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# Send the GET request and examine the resutls
results = requests.get(url).json()

# Borrow the get_category_type function from the Foursquare lab.
# Function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Clean the json and structure it into a pandas dataframe
venues = results['response']['groups'][0]['items']    
nearby_venues = json_normalize(venues) # flatten JSON

# Filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# Filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# Clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
print('{} venues were returned by Foursquare for North East Singapore.'.format(nearby_venues.shape[0]))
nearby_venues.head()
# Out:
# 63 venues were returned by Foursquare for North East Singapore.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:38: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          name   categories       lat         lng
# 0                Cold Storage  Supermarket  1.310523  103.863945
# 1  Swimming Pool @ Hotel Boss         Pool  1.305803  103.860348
# 2          Red Eye Smokehouse    BBQ Joint  1.310672  103.861050
# 3              NTUC FairPrice  Supermarket  1.308948  103.861953
# 4      Tolido's Espresso Nook         Café  1.304399  103.860686

# %%
# North West Singapore
# Explore the first neighborhood in our dataframe
# Get the neighborhood's latitude and longitude values.
neighborhood_latitude = nw.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = nw.loc[0, 'Longitude'] # neighborhood longitude value
neighborhood_name = nw.loc[0, 'General Location'] # neighborhood name

# Get the top 100 venues that are in North West Singapore within a radius of 500 meters
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# Send the GET request and examine the resutls
results = requests.get(url).json()

# Borrow the get_category_type function from the Foursquare lab.
# Function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Clean the json and structure it into a pandas dataframe
venues = results['response']['groups'][0]['items']    
nearby_venues = json_normalize(venues) # flatten JSON

# Filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# Filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# Clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
print('{} venues were returned by Foursquare for North West Singapore.'.format(nearby_venues.shape[0]))
nearby_venues.head()
# Out:
# 41 venues were returned by Foursquare for North West Singapore.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:38: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                              name            categories       lat         lng
# 0                Shangri-La Hotel                 Hotel  1.311232  103.826376
# 1  Valley Wing | Shangri-La Hotel                 Hotel  1.311753  103.827038
# 2   Treetops Executive Residences                 Hotel  1.308467  103.826900
# 3              Origin Grill & Bar            Steakhouse  1.311556  103.826641
# 4                    Shang Palace  Cantonese Restaurant  1.310978  103.826657

# %%
# South East Singapore
# Explore the first neighborhood in our dataframe
# Get the neighborhood's latitude and longitude values.
neighborhood_latitude = se.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = se.loc[0, 'Longitude'] # neighborhood longitude value
neighborhood_name = se.loc[0, 'General Location'] # neighborhood name

# Get the top 100 venues that are in South East Singapore within a radius of 500 meters
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# Send the GET request and examine the resutls
results = requests.get(url).json()

# Borrow the get_category_type function from the Foursquare lab.
# Function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Clean the json and structure it into a pandas dataframe
venues = results['response']['groups'][0]['items']    
nearby_venues = json_normalize(venues) # flatten JSON

# Filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# Filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# Clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
print('{} venues were returned by Foursquare for South East Singapore.'.format(nearby_venues.shape[0]))
nearby_venues.head()
# Out:
# 22 venues were returned by Foursquare for South East Singapore.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:38: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                 name  ...         lng
# 0                     The Skewer Bar  ...  103.883870
# 1            J.B. Ah Meng Restaurant  ...  103.886182
# 2      Hong Qin Fish & Duck Porridge  ...  103.885663
# 3  Sik Bao Sin (Desmond's Creations)  ...  103.887825
# 4          L32 手工面 Hand Made Noodles  ...  103.887060
#
# [5 rows x 4 columns]

# %%
# South West Singapore
# Explore the first neighborhood in our dataframe
# Get the neighborhood's latitude and longitude values.
neighborhood_latitude = sw.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = sw.loc[0, 'Longitude'] # neighborhood longitude value
neighborhood_name = sw.loc[0, 'General Location'] # neighborhood name

# Get the top 100 venues that are in South West Singapore within a radius of 500 meters
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# Send the GET request and examine the resutls
results = requests.get(url).json()

# Borrow the get_category_type function from the Foursquare lab.
# Function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Clean the json and structure it into a pandas dataframe
venues = results['response']['groups'][0]['items']    
nearby_venues = json_normalize(venues) # flatten JSON

# Filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# Filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# Clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
print('{} venues were returned by Foursquare for South West Singapore.'.format(nearby_venues.shape[0]))
nearby_venues.head()
# Out:
# 12 venues were returned by Foursquare for South West Singapore.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:38: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                    name          categories       lat         lng
# 0   The University Club   French Restaurant  1.293032  103.773196
# 1    Dario Pizza & More  Italian Restaurant  1.292517  103.768233
# 2           The Scholar  Chinese Restaurant  1.293268  103.773096
# 3  The Ridge Bar @ NUSS              Lounge  1.293646  103.773311
# 4     Café On The Ridge          Restaurant  1.293881  103.773350

# %%
# Function to repeat the same process to all area
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # Create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # Make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # Return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Area', 
                  'Area Latitude', 
                  'Area Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# Run the above function on each neighborhood and create a new dataframe
central_venues = getNearbyVenues(names=central['General Location'],
                                   latitudes=central['Latitude'],
                                   longitudes=central['Longitude']
                                  )

# Check the size of the resulting dataframe
print(central_venues.shape)
central_venues.head()
# Out:
# Raffles Place
# Cecil
# Marina
# People's Park
# Anson
# Tanjong Pagar
# Bukit Merah
# Queenstown
# Tiong Bahru
# Telok Blangah
# Habourfront
# High Street
# Beach Road
# Middle Road
# Golden Mile
# Little India
# Jalan Besar
# Orchard
# Cairnhill
# River Valley
# Tanglin
# Bidadari
# (1543, 7)
#             Area  Area Latitude  ...  Venue Longitude           Venue Category
# 0  Raffles Place        1.28468  ...       103.850815     Gym / Fitness Center
# 1  Raffles Place        1.28468  ...       103.851151             Cocktail Bar
# 2  Raffles Place        1.28468  ...       103.851177              Salad Place
# 3  Raffles Place        1.28468  ...       103.850933  Comfort Food Restaurant
# 4  Raffles Place        1.28468  ...       103.852673           Sandwich Place
#
# [5 rows x 7 columns]

# %%
# Run the above function on each neighborhood and create a new dataframe
ne_venues = getNearbyVenues(names=ne['General Location'],
                                   latitudes=ne['Latitude'],
                                   longitudes=ne['Longitude']
                                  )

# Check the size of the resulting dataframe
print(ne_venues.shape)
ne_venues.head()
# Out:
# Lavender
# Novena
# Balestier
# Toa Payoh
# Serangoon
# MacPherson
# Braddell
# Potong Pasir
# Serangoon Garden
# Hougang
# Punggol
# Bishan
# Ang Mo Kio
# Upper Thomson
# Springleaf
# Seletar
# (589, 7)
#        Area  Area Latitude  ...  Venue Longitude Venue Category
# 0  Lavender        1.30783  ...       103.863945    Supermarket
# 1  Lavender        1.30783  ...       103.860348           Pool
# 2  Lavender        1.30783  ...       103.861050      BBQ Joint
# 3  Lavender        1.30783  ...       103.861953    Supermarket
# 4  Lavender        1.30783  ...       103.860686           Café
#
# [5 rows x 7 columns]

# %%
# Run the above function on each neighborhood and create a new dataframe
nw_venues = getNearbyVenues(names=nw['General Location'],
                                   latitudes=nw['Latitude'],
                                   longitudes=nw['Longitude']
                                  )

# Check the size of the resulting dataframe
print(nw_venues.shape)
nw_venues.head()
# Out:
# Ardmore
# Bukit Timah
# Watten Estate
# Thomson
# Upper Bukit Timah
# Ulu Pandan
# Dairy Farm
# Bukit Panjang
# Choa Chu Kang
# Kranji
# Woodgrove
# Woodlands
# Yishun
# Sembawang
# Senoko
# (196, 7)
#       Area  Area Latitude  ...  Venue Longitude        Venue Category
# 0  Ardmore         1.3098  ...       103.826376                 Hotel
# 1  Ardmore         1.3098  ...       103.827038                 Hotel
# 2  Ardmore         1.3098  ...       103.826900                 Hotel
# 3  Ardmore         1.3098  ...       103.826641            Steakhouse
# 4  Ardmore         1.3098  ...       103.826657  Cantonese Restaurant
#
# [5 rows x 7 columns]

# %%
# Run the above function on each neighborhood and create a new dataframe
se_venues = getNearbyVenues(names=se['General Location'],
                                   latitudes=se['Latitude'],
                                   longitudes=se['Longitude']
                                  )

# Check the size of the resulting dataframe
print(se_venues.shape)
se_venues.head()
# Out:
# Geylang
# Eunos
# Aljunied
# Katong
# Joo Chiat
# Amber Road
# Bedok
# Upper East Coast
# Eastwood
# Kew Drive
# Loyang
# Changi
# Simei
# Tampines
# Pasir Ris
# (355, 7)
#       Area  Area Latitude  ...  Venue Longitude        Venue Category
# 0  Geylang        1.31488  ...       103.883870             BBQ Joint
# 1  Geylang        1.31488  ...       103.886182    Chinese Restaurant
# 2  Geylang        1.31488  ...       103.885663    Chinese Restaurant
# 3  Geylang        1.31488  ...       103.887825  Cantonese Restaurant
# 4  Geylang        1.31488  ...       103.887060          Noodle House
#
# [5 rows x 7 columns]

# %%
# Run the above function on each neighborhood and create a new dataframe
sw_venues = getNearbyVenues(names=sw['General Location'],
                                   latitudes=sw['Latitude'],
                                   longitudes=sw['Longitude']
                                  )

# Check the size of the resulting dataframe
print(sw_venues.shape)
sw_venues.head()
# Out:
# Pasir Panjang
# Hong Leong Garden
# Clementi New Town
# Farrer Park
# Holland Road
# Clementi Park
# Penjuru
# Jurong
# Pioneer
# Tuas
# Hillview
# Lim Chu Kang
# Tengah
# (197, 7)
#             Area  Area Latitude  ...  Venue Longitude      Venue Category
# 0  Pasir Panjang        1.29073  ...       103.773196   French Restaurant
# 1  Pasir Panjang        1.29073  ...       103.768233  Italian Restaurant
# 2  Pasir Panjang        1.29073  ...       103.773096  Chinese Restaurant
# 3  Pasir Panjang        1.29073  ...       103.773311              Lounge
# 4  Pasir Panjang        1.29073  ...       103.773350          Restaurant
#
# [5 rows x 7 columns]

# %% [markdown]
# Central Singapore

# %%
# One hot encoding
central_onehot = pd.get_dummies(central_venues[['Venue Category']], prefix="", prefix_sep="")

# Add neighborhood column back to dataframe
central_onehot['Area'] = central_venues['Area'] 

# Move neighborhood column to the first column
fixed_columns = [central_onehot.columns[-1]] + list(central_onehot.columns[:-1])
central_onehot = central_onehot[fixed_columns]

# Examine the new dataframe size after one hot encoding
print('{} rows were returned after one hot encoding.'.format(central_onehot.shape[0]))

# Group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
central_grouped = central_onehot.groupby('Area').mean().reset_index()

# Examine the new dataframe size after one hot encoding
print('{} rows were returned after grouping.'.format(central_grouped.shape[0]))
# Out:
# 1543 rows were returned after one hot encoding.
# 22 rows were returned after grouping.

# %%
# Print each neighborhood along with the top 5 most common venues
num_top_venues = 5

for hood in central_grouped['Area']:
    print("----"+hood+"----")
    temp = central_grouped[central_grouped['Area'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Anson----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1  Japanese Restaurant  0.10
# 2                Hotel  0.05
# 3               Bakery  0.04
# 4                 Café  0.04
#
#
# ----Beach Road----
#              venue  freq
# 0  Thai Restaurant  0.09
# 1            Hotel  0.07
# 2     Cocktail Bar  0.05
# 3             Café  0.05
# 4           Bakery  0.05
#
#
# ----Bidadari----
#                   venue  freq
# 0           Bus Station  0.19
# 1  Fast Food Restaurant  0.12
# 2     Convenience Store  0.12
# 3           Coffee Shop  0.12
# 4           Supermarket  0.06
#
#
# ----Bukit Merah----
#                   venue  freq
# 0  Fast Food Restaurant  0.12
# 1            Food Court  0.12
# 2           Supermarket  0.06
# 3     Indian Restaurant  0.06
# 4    Chinese Restaurant  0.06
#
#
# ----Cairnhill----
#                  venue  freq
# 0                Hotel  0.12
# 1                 Café  0.09
# 2  Japanese Restaurant  0.08
# ...

# %%
# Put into a pandas dataframe

# Write a function to sort the venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# Create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 8

indicators = ['st', 'nd', 'rd']

# Create columns according to number of top venues
columns = ['Area']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# Create a new dataframe
areas_venues_sorted = pd.DataFrame(columns=columns)
areas_venues_sorted['Area'] = central_grouped['Area']

for ind in np.arange(central_grouped.shape[0]):
    areas_venues_sorted.iloc[ind, 1:] = return_most_common_venues(central_grouped.iloc[ind, :], num_top_venues)

areas_venues_sorted.head()
# Out:
#           Area  ...  8th Most Common Venue
# 0        Anson  ...              BBQ Joint
# 1   Beach Road  ...  Indonesian Restaurant
# 2     Bidadari  ...            Snack Place
# 3  Bukit Merah  ...           Noodle House
# 4    Cairnhill  ...                   Pool
#
# [5 rows x 9 columns]

# %%
from sklearn.cluster import KMeans

# Set number of clusters
kclusters = 3

central_grouped_clustering = central_grouped.drop('Area', 1)

# Run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(central_grouped_clustering)

# Check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
central_merged = central

# Add clustering labels
central_merged['Cluster Labels'] = kmeans.labels_

# Merge central_grouped with central to add latitude/longitude for each neighborhood
central_merged = central_merged.join(areas_venues_sorted.set_index('Area'), on='General Location')

central_merged.head()
# Out:
#    Postcode General Location  ... 7th Most Common Venue  8th Most Common Venue
# 0     48616    Raffles Place  ...  Gym / Fitness Center              Hotel Bar
# 1     69531            Cecil  ...          Cocktail Bar   Gym / Fitness Center
# 2     18985           Marina  ...                 Hotel             Food Court
# 3     59108    People's Park  ...   Japanese Restaurant     Italian Restaurant
# 4     79914            Anson  ...                Bakery              BBQ Joint
#
# [5 rows x 14 columns]

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# Finally, let's visualize the resulting clusters
# Create map 
central_clusters = folium.Map(location=[central_latitude, central_longitude], zoom_start=13)

# Set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(central_merged['Latitude'], central_merged['Longitude'], central_merged['General Location'], central_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(central_clusters)
       
central_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# North East

# %%
# One hot encoding
ne_onehot = pd.get_dummies(ne_venues[['Venue Category']], prefix="", prefix_sep="")

# Add neighborhood column back to dataframe
ne_onehot['Area'] = ne_venues['Area'] 

# Move neighborhood column to the first column
fixed_columns = [ne_onehot.columns[-1]] + list(ne_onehot.columns[:-1])
ne_onehot = ne_onehot[fixed_columns]

# Examine the new dataframe size after one hot encoding
print('{} rows were returned after one hot encoding.'.format(ne_onehot.shape[0]))

# Group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
ne_grouped = ne_onehot.groupby('Area').mean().reset_index()

# Examine the new dataframe size after one hot encoding
print('{} rows were returned after grouping.'.format(ne_grouped.shape[0]))
# Out:
# 589 rows were returned after one hot encoding.
# 16 rows were returned after grouping.

# %%
# Print each neighborhood along with the top 5 most common venues
num_top_venues = 5

for hood in ne_grouped['Area']:
    print("----"+hood+"----")
    temp = ne_grouped[ne_grouped['Area'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Ang Mo Kio----
#               venue  freq
# 0       Coffee Shop  0.10
# 1        Food Court  0.10
# 2       Supermarket  0.05
# 3      Dessert Shop  0.05
# 4  Asian Restaurant  0.05
#
#
# ----Balestier----
#                 venue  freq
# 0  Chinese Restaurant  0.16
# 1    Asian Restaurant  0.13
# 2   Indian Restaurant  0.08
# 3               Hotel  0.08
# 4        Noodle House  0.08
#
#
# ----Bishan----
#              venue  freq
# 0       Food Court  0.09
# 1      Coffee Shop  0.09
# 2             Café  0.07
# 3  Bubble Tea Shop  0.07
# 4   Ice Cream Shop  0.07
#
#
# ----Braddell----
#                 venue  freq
# 0  Chinese Restaurant  0.29
# 1  Seafood Restaurant  0.21
# 2         Bus Station  0.07
# 3               Trail  0.07
# 4         Coffee Shop  0.07
#
#
# ----Hougang----
#                            venue  freq
# 0                    Bus Station   0.2
# 1               Asian Restaurant   0.2
# 2                    Coffee Shop   0.1
# ...

# %%
# Create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 8

indicators = ['st', 'nd', 'rd']

# Create columns according to number of top venues
columns = ['Area']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# Create a new dataframe
areas_venues_sorted = pd.DataFrame(columns=columns)
areas_venues_sorted['Area'] = ne_grouped['Area']

for ind in np.arange(ne_grouped.shape[0]):
    areas_venues_sorted.iloc[ind, 1:] = return_most_common_venues(ne_grouped.iloc[ind, :], num_top_venues)

areas_venues_sorted.head()
# Out:
#          Area 1st Most Common Venue  ... 7th Most Common Venue 8th Most Common Venue
# 0  Ang Mo Kio           Coffee Shop  ...  Fast Food Restaurant    Seafood Restaurant
# 1   Balestier    Chinese Restaurant  ...     Indian Restaurant                  Food
# 2      Bishan           Coffee Shop  ...   Japanese Restaurant    Chinese Restaurant
# 3    Braddell    Chinese Restaurant  ...            Food Court                Market
# 4     Hougang           Bus Station  ...                Bakery           Coffee Shop
#
# [5 rows x 9 columns]

# %%
# Set number of clusters
kclusters = 3

ne_grouped_clustering = ne_grouped.drop('Area', 1)

# Run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(ne_grouped_clustering)

# Check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
ne_merged = ne

# Add clustering labels
ne_merged['Cluster Labels'] = kmeans.labels_

# Merge ne_grouped with north east to add latitude/longitude for each neighborhood
ne_merged = ne_merged.join(areas_venues_sorted.set_index('Area'), on='General Location')

ne_merged.head()
# Out:
#    Postcode General Location  ... 7th Most Common Venue  8th Most Common Venue
# 0    208767         Lavender  ...                Bakery                   Pool
# 1    307684           Novena  ...      Asian Restaurant     Italian Restaurant
# 2    329894        Balestier  ...     Indian Restaurant                   Food
# 3    318995        Toa Payoh  ...             Gastropub             Steakhouse
# 4    218108        Serangoon  ...            Food Court             Restaurant
#
# [5 rows x 14 columns]

# %% [markdown]
# North West

# %%
# One hot encoding
nw_onehot = pd.get_dummies(nw_venues[['Venue Category']], prefix="", prefix_sep="")

# Add neighborhood column back to dataframe
nw_onehot['Area'] = nw_venues['Area'] 

# Move neighborhood column to the first column
fixed_columns = [nw_onehot.columns[-1]] + list(nw_onehot.columns[:-1])
nw_onehot = nw_onehot[fixed_columns]

# Examine the new dataframe size after one hot encoding
print('{} rows were returned after one hot encoding.'.format(nw_onehot.shape[0]))

# Group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
nw_grouped = nw_onehot.groupby('Area').mean().reset_index()

# Examine the new dataframe size after one hot encoding
print('{} rows were returned after grouping.'.format(nw_grouped.shape[0]))
# Out:
# 196 rows were returned after one hot encoding.
# 15 rows were returned after grouping.

# %%
# Print each neighborhood along with the top 5 most common venues
num_top_venues = 5

for hood in nw_grouped['Area']:
    print("----"+hood+"----")
    temp = nw_grouped[nw_grouped['Area'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Ardmore----
#                  venue  freq
# 0                Hotel  0.24
# 1  Japanese Restaurant  0.07
# 2   Chinese Restaurant  0.05
# 3           Steakhouse  0.05
# 4                  Spa  0.05
#
#
# ----Bukit Panjang----
#                 venue  freq
# 0    Halal Restaurant  0.17
# 1       Grocery Store  0.17
# 2    Basketball Court  0.17
# 3         Supermarket  0.17
# 4  Light Rail Station  0.17
#
#
# ----Bukit Timah----
#                  venue  freq
# 0         Dance Studio  0.12
# 1        Track Stadium  0.12
# 2                 Café  0.12
# 3   Italian Restaurant  0.12
# 4  Japanese Restaurant  0.12
#
#
# ----Choa Chu Kang----
#                    venue  freq
# 0            Coffee Shop  0.12
# 1  Indonesian Restaurant  0.12
# 2            Karaoke Bar  0.06
# 3   Fast Food Restaurant  0.06
# 4      Convenience Store  0.06
#
#
# ----Dairy Farm----
#                     venue  freq
# 0                   Trail   0.5
# 1  Thrift / Vintage Store   0.5
# ...

# %%
# Create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 8

indicators = ['st', 'nd', 'rd']

# Create columns according to number of top venues
columns = ['Area']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# Create a new dataframe
areas_venues_sorted = pd.DataFrame(columns=columns)
areas_venues_sorted['Area'] = nw_grouped['Area']

for ind in np.arange(nw_grouped.shape[0]):
    areas_venues_sorted.iloc[ind, 1:] = return_most_common_venues(nw_grouped.iloc[ind, :], num_top_venues)

areas_venues_sorted.head()
# Out:
#             Area  ... 8th Most Common Venue
# 0        Ardmore  ...                Lounge
# 1  Bukit Panjang  ...     Convenience Store
# 2    Bukit Timah  ...    Italian Restaurant
# 3  Choa Chu Kang  ...       Bubble Tea Shop
# 4     Dairy Farm  ...          Dance Studio
#
# [5 rows x 9 columns]

# %%
# Set number of clusters
kclusters = 3

nw_grouped_clustering = nw_grouped.drop('Area', 1)

# Run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(nw_grouped_clustering)

# Check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
nw_merged = nw

# Add clustering labels
nw_merged['Cluster Labels'] = kmeans.labels_

# Merge nw_grouped with north west to add latitude/longitude for each neighborhood
nw_merged = nw_merged.join(areas_venues_sorted.set_index('Area'), on='General Location')

nw_merged.head()
# Out:
#    Postcode   General Location  ... 7th Most Common Venue  8th Most Common Venue
# 0    259962            Ardmore  ...              Wine Bar                 Lounge
# 1    259741        Bukit Timah  ...        Sandwich Place     Italian Restaurant
# 2    287630      Watten Estate  ...               Butcher    Japanese Restaurant
# 3    298191            Thomson  ...              Wine Bar           Cocktail Bar
# 4    678072  Upper Bukit Timah  ...                  Café   Cantonese Restaurant
#
# [5 rows x 14 columns]

# %% [markdown]
# South East

# %%
# One hot encoding
se_onehot = pd.get_dummies(se_venues[['Venue Category']], prefix="", prefix_sep="")

# Add neighborhood column back to dataframe
se_onehot['Area'] = se_venues['Area'] 

# Move neighborhood column to the first column
fixed_columns = [se_onehot.columns[-1]] + list(se_onehot.columns[:-1])
se_onehot = se_onehot[fixed_columns]

# Examine the new dataframe size after one hot encoding
print('{} rows were returned after one hot encoding.'.format(se_onehot.shape[0]))

# Group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
se_grouped = se_onehot.groupby('Area').mean().reset_index()

# Examine the new dataframe size after one hot encoding
print('{} rows were returned after grouping.'.format(se_grouped.shape[0]))
# Out:
# 355 rows were returned after one hot encoding.
# 15 rows were returned after grouping.

# %%
# Print each neighborhood along with the top 5 most common venues
num_top_venues = 5

for hood in se_grouped['Area']:
    print("----"+hood+"----")
    temp = se_grouped[se_grouped['Area'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Aljunied----
#           venue  freq
# 0    Food Court  0.18
# 1   Gas Station  0.18
# 2   Coffee Shop  0.09
# 3        Bistro  0.09
# 4  Soccer Field  0.09
#
#
# ----Amber Road----
#                  venue  freq
# 0                 Café  0.05
# 1          Coffee Shop  0.05
# 2  Japanese Restaurant  0.05
# 3                Hotel  0.05
# 4        Shopping Mall  0.04
#
#
# ----Bedok----
#                 venue  freq
# 0    Asian Restaurant  0.16
# 1        Dessert Shop  0.08
# 2        Noodle House  0.08
# 3  Chinese Restaurant  0.08
# 4    Malay Restaurant  0.08
#
#
# ----Changi----
#                 venue  freq
# 0   Indian Restaurant  0.12
# 1  Chinese Restaurant  0.12
# 2            Bus Stop  0.08
# 3   Convenience Store  0.04
# 4           Gastropub  0.04
#
#
# ----Eastwood----
#             venue  freq
# 0      Food Court  0.17
# 1  Ice Cream Shop  0.17
# 2    Dessert Shop  0.17
# 3     Bus Station  0.17
# 4     Supermarket  0.17
#
#
# ----Eunos----
# ...

# %%
# Create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 8

indicators = ['st', 'nd', 'rd']

# Create columns according to number of top venues
columns = ['Area']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# Create a new dataframe
areas_venues_sorted = pd.DataFrame(columns=columns)
areas_venues_sorted['Area'] = se_grouped['Area']

for ind in np.arange(se_grouped.shape[0]):
    areas_venues_sorted.iloc[ind, 1:] = return_most_common_venues(se_grouped.iloc[ind, :], num_top_venues)

areas_venues_sorted.head()
# Out:
#          Area 1st Most Common Venue  ... 7th Most Common Venue 8th Most Common Venue
# 0    Aljunied           Gas Station  ...                Bakery                Bistro
# 1  Amber Road   Japanese Restaurant  ...     Indian Restaurant      Asian Restaurant
# 2       Bedok      Asian Restaurant  ...            Playground                  Café
# 3      Changi    Chinese Restaurant  ...           Coffee Shop     Electronics Store
# 4    Eastwood           Bus Station  ...           Yoga Studio     Electronics Store
#
# [5 rows x 9 columns]

# %%
# Set number of clusters
kclusters = 3

se_grouped_clustering = se_grouped.drop('Area', 1)

# Run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(se_grouped_clustering)

# Check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
se_merged = se

# Add clustering labels
se_merged['Cluster Labels'] = kmeans.labels_

# Merge se_grouped with south east to add latitude/longitude for each neighborhood
se_merged = se_merged.join(areas_venues_sorted.set_index('Area'), on='General Location')

se_merged.head()
# Out:
#    Postcode General Location  ... 7th Most Common Venue  8th Most Common Venue
# 0    388070          Geylang  ...   Japanese Restaurant     Dim Sum Restaurant
# 1    400415            Eunos  ...         Shopping Mall                  Hotel
# 2    380125         Aljunied  ...                Bakery                 Bistro
# 3    437092           Katong  ...              Bus Stop    Fried Chicken Joint
# 4    420001        Joo Chiat  ...            Restaurant            Snack Place
#
# [5 rows x 14 columns]

# %% [markdown]
# South West

# %%
# One hot encoding
sw_onehot = pd.get_dummies(sw_venues[['Venue Category']], prefix="", prefix_sep="")

# Add neighborhood column back to dataframe
sw_onehot['Area'] = sw_venues['Area'] 

# Move neighborhood column to the first column
fixed_columns = [sw_onehot.columns[-1]] + list(sw_onehot.columns[:-1])
sw_onehot = sw_onehot[fixed_columns]

# Examine the new dataframe size after one hot encoding
print('{} rows were returned after one hot encoding.'.format(sw_onehot.shape[0]))

# Group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
sw_grouped = sw_onehot.groupby('Area').mean().reset_index()

# Examine the new dataframe size after one hot encoding
print('{} rows were returned after grouping.'.format(sw_grouped.shape[0]))
# Out:
# 197 rows were returned after one hot encoding.
# 13 rows were returned after grouping.

# %%
# Print each neighborhood along with the top 5 most common venues
num_top_venues = 5

for hood in sw_grouped['Area']:
    print("----"+hood+"----")
    temp = sw_grouped[sw_grouped['Area'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Clementi New Town----
#          venue  freq
# 0   Food Court  0.17
# 1       Bakery  0.13
# 2         Café  0.09
# 3  Gelato Shop  0.04
# 4     Pie Shop  0.04
#
#
# ----Clementi Park----
#                   venue  freq
# 0         Military Base  0.25
# 1            Playground  0.12
# 2  Gym / Fitness Center  0.12
# 3              Bus Line  0.12
# 4                 Plaza  0.12
#
#
# ----Farrer Park----
#                 venue  freq
# 0   Indian Restaurant  0.20
# 1  Chinese Restaurant  0.09
# 2                Café  0.09
# 3               Hotel  0.06
# 4    Asian Restaurant  0.04
#
#
# ----Hillview----
#                            venue  freq
# 0                       Gym Pool  0.11
# 1             Chinese Restaurant  0.05
# 2                    Video Store  0.05
# 3  Vegetarian / Vegan Restaurant  0.05
# 4                    Supermarket  0.05
#
#
# ----Holland Road----
#                 venue  freq
# 0              Bakery  0.09
# 1      Ice Cream Shop  0.07
# ...

# %%
# Create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 8

indicators = ['st', 'nd', 'rd']

# Create columns according to number of top venues
columns = ['Area']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# Create a new dataframe
areas_venues_sorted = pd.DataFrame(columns=columns)
areas_venues_sorted['Area'] = sw_grouped['Area']

for ind in np.arange(sw_grouped.shape[0]):
    areas_venues_sorted.iloc[ind, 1:] = return_most_common_venues(sw_grouped.iloc[ind, :], num_top_venues)

areas_venues_sorted.head()
# Out:
#                 Area  ... 8th Most Common Venue
# 0  Clementi New Town  ...    Chinese Restaurant
# 1      Clementi Park  ...            Food Court
# 2        Farrer Park  ...      Community Center
# 3           Hillview  ...  Gym / Fitness Center
# 4       Holland Road  ...           Pizza Place
#
# [5 rows x 9 columns]

# %%
# Set number of clusters
kclusters = 3

sw_grouped_clustering = sw_grouped.drop('Area', 1)

# Run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sw_grouped_clustering)

# Check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
sw_merged = sw

# Add clustering labels
sw_merged['Cluster Labels'] = kmeans.labels_

# Merge sw_grouped with south west to add latitude/longitude for each neighborhood
sw_merged = sw_merged.join(areas_venues_sorted.set_index('Area'), on='General Location')

sw_merged.head()
# Out:
#    Postcode  ...    8th Most Common Venue
# 0    118719  ...         Malay Restaurant
# 1    127935  ...  Comfort Food Restaurant
# 2    120101  ...       Chinese Restaurant
# 3    217562  ...         Community Center
# 4    278977  ...              Pizza Place
#
# [5 rows x 14 columns]

# %% [markdown]
# Results

# %% [markdown]
# Central Singapore

# %%
# Cluster 1 for Central Singapore
central_merged.loc[central_merged['Cluster Labels'] == 0, central_merged.columns[[2] + list(range(5, central_merged.shape[1]))]]
# Out:
#               Regions  ...  8th Most Common Venue
# 0   Central Singapore  ...              Hotel Bar
# 1   Central Singapore  ...   Gym / Fitness Center
# 3   Central Singapore  ...     Italian Restaurant
# 4   Central Singapore  ...              BBQ Joint
# 5   Central Singapore  ...     Spanish Restaurant
# 6   Central Singapore  ...           Noodle House
# 7   Central Singapore  ...         Ice Cream Shop
# 8   Central Singapore  ...           Noodle House
# 9   Central Singapore  ...         Cosmetics Shop
# 11  Central Singapore  ...          Shopping Mall
# 12  Central Singapore  ...  Indonesian Restaurant
# 13  Central Singapore  ...                 Bakery
# 14  Central Singapore  ...      French Restaurant
# 15  Central Singapore  ...     Chinese Restaurant
# 16  Central Singapore  ...             Food Court
# 17  Central Singapore  ...     Chinese Restaurant
# 18  Central Singapore  ...                   Pool
# 19  Central Singapore  ...      Indian Restaurant
# ...

# %%
# Cluster 2 for Central Singapore
central_merged.loc[central_merged['Cluster Labels'] == 1, central_merged.columns[[2] + list(range(5, central_merged.shape[1]))]]
# Out:
#               Regions  ...  8th Most Common Venue
# 10  Central Singapore  ...     Frozen Yogurt Shop
#
# [1 rows x 10 columns]

# %%
# Cluster 3 for Central Singapore
central_merged.loc[central_merged['Cluster Labels'] == 2, central_merged.columns[[2] + list(range(5, central_merged.shape[1]))]]
# Out:
#              Regions  ...  8th Most Common Venue
# 2  Central Singapore  ...             Food Court
#
# [1 rows x 10 columns]

# %% [markdown]
# North East Singapore

# %%
# Cluster 1 for North East Singapore
ne_merged.loc[ne_merged['Cluster Labels'] == 0, ne_merged.columns[[2] + list(range(5, ne_merged.shape[1]))]]
# Out:
#       Regions  Cluster Labels  ... 7th Most Common Venue 8th Most Common Venue
# 4  North East               0  ...            Food Court            Restaurant
# 8  North East               0  ...     Indian Restaurant          Noodle House
# 9  North East               0  ...                Bakery           Coffee Shop
#
# [3 rows x 10 columns]

# %%
# Cluster 2 for North East Singapore
ne_merged.loc[ne_merged['Cluster Labels'] == 1, ne_merged.columns[[2] + list(range(5, ne_merged.shape[1]))]]
# Out:
#        Regions  Cluster Labels  ... 7th Most Common Venue 8th Most Common Venue
# 10  North East               1  ...   Fried Chicken Joint     French Restaurant
#
# [1 rows x 10 columns]

# %%
# Cluster 3 for North East Singapore
ne_merged.loc[ne_merged['Cluster Labels'] == 2, ne_merged.columns[[2] + list(range(5, ne_merged.shape[1]))]]
# Out:
#        Regions  ...  8th Most Common Venue
# 0   North East  ...                   Pool
# 1   North East  ...     Italian Restaurant
# 2   North East  ...                   Food
# 3   North East  ...             Steakhouse
# 5   North East  ...       Asian Restaurant
# 6   North East  ...                 Market
# 7   North East  ...           Soccer Field
# 11  North East  ...     Chinese Restaurant
# 12  North East  ...     Seafood Restaurant
# 13  North East  ...       Sushi Restaurant
# 14  North East  ...      German Restaurant
# 15  North East  ...    Dumpling Restaurant
#
# [12 rows x 10 columns]

# %% [markdown]
# North West Singapore

# %%
# Cluster 1 for North West Singapore
nw_merged.loc[nw_merged['Cluster Labels'] == 0, nw_merged.columns[[2] + list(range(5, nw_merged.shape[1]))]]
# Out:
#       Regions  Cluster Labels  ... 7th Most Common Venue 8th Most Common Venue
# 4  North West               0  ...                  Café  Cantonese Restaurant
#
# [1 rows x 10 columns]

# %%
# Cluster 2 for North West Singapore
nw_merged.loc[nw_merged['Cluster Labels'] == 1, nw_merged.columns[[2] + list(range(5, nw_merged.shape[1]))]]
# Out:
#        Regions  Cluster Labels  ... 7th Most Common Venue 8th Most Common Venue
# 0   North West               1  ...              Wine Bar                Lounge
# 1   North West               1  ...        Sandwich Place    Italian Restaurant
# 2   North West               1  ...               Butcher   Japanese Restaurant
# 3   North West               1  ...              Wine Bar          Cocktail Bar
# 5   North West               1  ...     Indian Restaurant          Dessert Shop
# 6   North West               1  ...     Convenience Store          Dance Studio
# 8   North West               1  ...     Convenience Store       Bubble Tea Shop
# 9   North West               1  ...          Dance Studio         Deli / Bodega
# 10  North West               1  ...           Coffee Shop         Deli / Bodega
# 11  North West               1  ...              Wine Bar          Dessert Shop
# 12  North West               1  ...         Shopping Mall     Indian Restaurant
# ...

# %%
# Cluster 3 for North West Singapore
nw_merged.loc[nw_merged['Cluster Labels'] == 2, nw_merged.columns[[2] + list(range(5, nw_merged.shape[1]))]]
# Out:
#       Regions  Cluster Labels  ... 7th Most Common Venue 8th Most Common Venue
# 7  North West               2  ...               Dog Run     Convenience Store
#
# [1 rows x 10 columns]

# %% [markdown]
# South East Singapore

# %%
# Cluster 1 for South East Singapore
se_merged.loc[se_merged['Cluster Labels'] == 0, se_merged.columns[[2] + list(range(5, se_merged.shape[1]))]]
# Out:
#       Regions  Cluster Labels  ... 7th Most Common Venue 8th Most Common Venue
# 4  South East               0  ...            Restaurant           Snack Place
# 9  South East               0  ...           Yoga Studio     Electronics Store
#
# [2 rows x 10 columns]

# %%
# Cluster 2 for South East Singapore
se_merged.loc[se_merged['Cluster Labels'] == 1, se_merged.columns[[2] + list(range(5, se_merged.shape[1]))]]
# Out:
#        Regions  Cluster Labels  ... 7th Most Common Venue 8th Most Common Venue
# 0   South East               1  ...   Japanese Restaurant    Dim Sum Restaurant
# 1   South East               1  ...         Shopping Mall                 Hotel
# 2   South East               1  ...                Bakery                Bistro
# 3   South East               1  ...              Bus Stop   Fried Chicken Joint
# 5   South East               1  ...     Indian Restaurant      Asian Restaurant
# 6   South East               1  ...            Playground                  Café
# 7   South East               1  ...     Electronics Store           Coffee Shop
# 8   South East               1  ...           Yoga Studio     Electronics Store
# 10  South East               1  ...                   Spa     Convenience Store
# 12  South East               1  ...                  Café          Noodle House
# 13  South East               1  ...           Bus Station          Dessert Shop
# ...

# %%
# Cluster 3 for South East Singapore
se_merged.loc[se_merged['Cluster Labels'] == 2, se_merged.columns[[2] + list(range(5, se_merged.shape[1]))]]
# Out:
#        Regions  Cluster Labels  ... 7th Most Common Venue 8th Most Common Venue
# 11  South East               2  ...           Coffee Shop     Electronics Store
#
# [1 rows x 10 columns]

# %% [markdown]
# South West Singapore

# %%
# Cluster 1 for South West Singapore
sw_merged.loc[sw_merged['Cluster Labels'] == 0, sw_merged.columns[[2] + list(range(5, sw_merged.shape[1]))]]
# Out:
#        Regions  Cluster Labels  ... 7th Most Common Venue 8th Most Common Venue
# 11  South West               0  ...        Cosmetics Shop      Department Store
#
# [1 rows x 10 columns]

# %%
# Cluster 2 for South West Singapore
sw_merged.loc[sw_merged['Cluster Labels'] == 1, sw_merged.columns[[2] + list(range(5, sw_merged.shape[1]))]]
# Out:
#        Regions  ...    8th Most Common Venue
# 0   South West  ...         Malay Restaurant
# 1   South West  ...  Comfort Food Restaurant
# 2   South West  ...       Chinese Restaurant
# 3   South West  ...         Community Center
# 4   South West  ...              Pizza Place
# 5   South West  ...               Food Court
# 6   South West  ...             Dessert Shop
# 8   South West  ...           Cosmetics Shop
# 9   South West  ...         Department Store
# 10  South West  ...     Gym / Fitness Center
# 12  South West  ...             Dessert Shop
#
# [11 rows x 10 columns]

# %%
# Cluster 3 for South West Singapore
sw_merged.loc[sw_merged['Cluster Labels'] == 2, sw_merged.columns[[2] + list(range(5, sw_merged.shape[1]))]]
# Out:
#       Regions  Cluster Labels  ... 7th Most Common Venue    8th Most Common Venue
# 7  South West               2  ...    Italian Restaurant  Chinese Breakfast Place
#
# [1 rows x 10 columns]
